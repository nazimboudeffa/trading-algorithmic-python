# %%
import yfinance as yf
import pandas as pd
from datetime import timedelta, datetime

# %%
delta = timedelta(days=-300)
today = datetime.now()

data = yf.download("GC=F", today+delta)
TEMP = data.copy(deep=True)
TEMP = TEMP.dropna()
TEMP.to_csv("data"+"/"+"GC"+"_D1"+".csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#You have to make some changes in the file

# %%
# Make sure we only use the 'Close' column
data = gc[['Close']].copy()

# Compute SMAs
data['SMA_50'] = data['Close'].rolling(window=50).mean()
data['SMA_200'] = data['Close'].rolling(window=200).mean()

data
# Out:
# Price             Close       SMA_50    SMA_200
# Ticker             GC=F
# Date
# 2024-07-11  2415.000000          NaN        NaN
# 2024-07-12  2414.000000          NaN        NaN
# 2024-07-15  2422.899902          NaN        NaN
# 2024-07-16  2462.399902          NaN        NaN
# 2024-07-17  2454.800049          NaN        NaN
# ...                 ...          ...        ...
# 2025-04-30  3305.000000  3068.699995  2736.9210
# 2025-05-01  3210.000000  3074.511997  2740.6590
# 2025-05-02  3231.899902  3080.349995  2744.5445
# 2025-05-05  3311.300049  3087.823994  2748.8420
# 2025-05-06  3404.800049  3096.961997  2753.8885
#
# [207 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Flatten multi-level columns
# ----> 2 data.columns = data.columns.get_level_values(1)  # This pulls out 'GC=F', 'Date', etc.
#       4 # Now rename or select the correct columns
#       5 data = data.rename(columns={'Date': 'Date', 'GC=F': 'Close'})  # If 'GC=F' is the close price
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:2102, in Index._get_level_values(self, level)
#    2066 def _get_level_values(self, level) -> Index:
#    2067     """
#    2068     Return an Index of values for requested level.
#    2069
#    (...)   2100     Index(['a', 'b', 'c'], dtype='object')
#    2101     """
# -> 2102     self._validate_index_level(level)
#    2103     return self
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='GOLD Close Price', alpha=0.5)
plt.plot(data['SMA_50'], label='50-Day SMA', color='blue', alpha=0.75)
plt.plot(data['SMA_200'], label='200-Day SMA', color='orange', alpha=0.75)
plt.title('GOLD Price and Moving Averages')
plt.legend()
plt.show()

# %%
import plotly.express as px
fig = px.line(data, x=data.index, y='Close', title='Gold Price Over Time')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 2
#       1 import plotly.express as px
# ----> 2 fig = px.line(data, x=data.index, y='Close', title='Gold Price Over Time')
#       3 fig.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_chart_types.py:270, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, subtitle, template, width, height)
#     221 def line(
#     222     data_frame=None,
# ...
