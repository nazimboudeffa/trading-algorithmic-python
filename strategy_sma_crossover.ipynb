# %%
import yfinance as yf
import pandas as pd
from datetime import timedelta, datetime

# %%
delta = timedelta(days=-300)
today = datetime.now()

data = yf.download("GC=F", today+delta)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['SMA_50'] = data['Close'].rolling(window=50).mean()
data['SMA_200'] = data['Close'].rolling(window=200).mean()
data
# Out:
# Price             Close         High          Low         Open Volume  \
# Ticker             GC=F         GC=F         GC=F         GC=F   GC=F
# Date
# 2024-07-11  2415.000000  2416.699951  2378.699951  2378.699951     72
# 2024-07-12  2414.000000  2414.000000  2391.300049  2399.800049    355
# 2024-07-15  2422.899902  2436.000000  2422.899902  2430.000000    540
# 2024-07-16  2462.399902  2462.399902  2427.399902  2427.399902     93
# 2024-07-17  2454.800049  2473.100098  2454.800049  2472.899902     10
# ...                 ...          ...          ...          ...    ...
# 2025-04-30  3305.000000  3318.699951  3268.000000  3318.699951    207
# 2025-05-01  3210.000000  3275.000000  3198.600098  3272.899902   2131
# 2025-05-02  3231.899902  3257.000000  3225.000000  3239.899902   1349
# 2025-05-05  3311.300049  3315.699951  3239.699951  3242.699951   1349
# 2025-05-06  3400.600098  3448.199951  3383.899902  3448.100098  31228
#
# Price            SMA_50    SMA_200
# Ticker
# Date
# 2024-07-11          NaN        NaN
# 2024-07-12          NaN        NaN
# 2024-07-15          NaN        NaN
# 2024-07-16          NaN        NaN
# 2024-07-17          NaN        NaN
# ...                 ...        ...
# 2025-04-30  3068.699995  2736.9210
# 2025-05-01  3074.511997  2740.6590
# 2025-05-02  3080.349995  2744.5445
# 2025-05-05  3087.823994  2748.8420
# 2025-05-06  3096.877998  2753.8675
#
# [207 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='GOLD Close Price', alpha=0.5)
plt.plot(data['SMA_50'], label='50-Day SMA', color='blue', alpha=0.75)
plt.plot(data['SMA_200'], label='200-Day SMA', color='orange', alpha=0.75)
plt.title('GOLD Price and Moving Averages')
plt.legend()
plt.show()
